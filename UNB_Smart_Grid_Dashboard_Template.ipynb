# %%
# Import Dash components
import dash
import dash_auth
import dash_html_components as dhtml
import dash_core_components as dcc
from dash.dependencies import Input, Output, State

# Jupyter dash to view/deploy dashboard in notebook
from jupyter_dash import JupyterDash

# Import various libraries
import pandas as pd
import mysql.connector as sql
import time
from time import localtime
from pytz import timezone
import datetime
import plotly
from env_canada import ECData

# %%
# Create dash application
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = JupyterDash(__name__, external_stylesheets=external_stylesheets)

# %%
# User name and pass
VALID_USERNAME_PASSWORD_PAIRS = {
    'admin': 'password',
    'ben_nowell17': 'password'
}

# %%
auth = dash_auth.BasicAuth(
    app,
    VALID_USERNAME_PASSWORD_PAIRS
)

# %%
# Dataframes

# %%
# Determine all dataframes in forecasting database
forecasting_db = sql.connect(host="localhost",
                       user="data_loader",
                       passwd="data_loader_password",
                       database="dashboard_forecasting_graph")

tables_df = pd.read_sql('SHOW TABLES', forecasting_db)

# %%
def build_dataframes():
    global frames_dict, table_name_list
    table_name_list = tables_df.Tables_in_dashboard_forecasting_graph

    select_template = 'SELECT * FROM {table_name}'
    frames_dict = {}
    for tname in table_name_list:
        query = select_template.format(table_name = tname)
        frames_dict[tname] = pd.read_sql(query, forecasting_db)

# %%
build_dataframes()
dataframes = list(frames_dict.keys())
channels = frames_dict[dataframes[0]]

# %%
# Connnect to peak shaving database
peak_shaving_db = sql.connect(host="localhost",
                             user="data_loader",
                             passwd="data_loader_password",
                             database="dashboard_peak_shaving_graph")

# %%
def build_peak_shaving_df():
    global peak_shaving_df
    query = ("SELECT * FROM peak_shaving;")
    peak_shaving_df = pd.read_sql(query, peak_shaving_db)

# %%
build_peak_shaving_df()

# %%
#Layout

# %%
# Global Layout Settings
layout = dict(
    autosize=True,
    automargin=True,
    margin=dict(l=30, r=30, b=20, t=40),
    hovermode="closest",
    plot_bgcolor="#F9F9F9",
    paper_bgcolor="#F9F9F9",
    legend=dict(font=dict(size=10), orientation="h"),
),

pretty_container = {
    "borderRadius":"5px",
    "backgroundColor":"#f9f9f9",
    "margin":"10px",
    "padding":"15px",
    "position": "relative",
    "boxShadow": "2px 2px 2px lightgrey"
}

mini_container = {
    "borderRadius":"5px",
    "backgroundColor":"#f9f9f9",
    "margin":"10px",
    "padding":"15px",
    "position":"relative",
    "boxShadow":"2px 2px 2px lightgrey"
}

container_display = dict(
    display="flex"
)

# %%
# Create app layout
app.layout = dhtml.Div(
    [
        dhtml.Div(
            [
                dhtml.Div(
                    [
                        dhtml.Img(
                            src="data:image/jpeg;base64,...",
                            id="unb_logo",
                            style={
                                "height": "60px",
                                "width": "auto",
                                "margin-bottom": "25px",
                            },
                        )
                    ],
                    className="two columns",
                ),
                dhtml.Div(
                    [
                        dhtml.Div(
                            [
                                dhtml.H3(
                                    "Emera and NB Power Research Center for Smart Grid Technologies",
                                    style={
                                        "margin-bottom": "0px",
                                        "text-align": "center"
                                    },
                                ),
                                dhtml.H5(
                                    "EV Research Dashboard", 
                                    style={
                                        "margin-top": "0px",
                                        "text-align": "center"
                                    }
                                ),
                            ]
                        )
                    ],
                    className="eight columns",
                    id="title",
                ),
                dhtml.Div(
                    [
                        dhtml.A(
                            dhtml.Button("Researcher Access", id="researcher-button"),
                            href="http://34.70.91.46:8888",
                        )
                    ],
                    className="two columns",
                    id="button",
                ),
            ],
            id="header",
            className="row flex-display",
            style={"margin-bottom": "25px"},
        ),
        dhtml.Div(
            [
                dhtml.Div(
                    [
                        dhtml.H6(
                            "EV Forecasting",
                            style={
                                "textAlign": "center"
                            }
                        ),
                        dhtml.P(
                            "This dashboard shows a forecast of future impact by an increasing fleet of EVs.",
                            className="description_label"
                        ),
                        dhtml.Div(
                            id="live_clock",
                            children="Date and Time: "
                        ),
                        dcc.Interval(
                            id = "interval-component",
                            interval = 1*1000,
                            n_intervals = 0
                        ),
                        dhtml.Div(
                            id="current_weather"
                        ),
                        dcc.Interval(
                            id = "weather-interval",
                            interval = 60*1000,
                            n_intervals = 0
                        ),
                        dcc.Interval(
                            id = "forecasting-interval",
                            interval = 10*1000,
                            n_intervals = 0
                        ),
                        dhtml.Br(),
                        dhtml.Label(
                            ['Select Forecast Resolution:'
                            ],
                            style={
                                "textAlign": "center"
                            }
                        ),
                        dcc.Dropdown(
                            id="df_dropdown",
                            options= [{
                                'label': df,
                                'value': df} for df in dataframes
                                      ],
                            value=list(frames_dict.keys())[0],
                            searchable=False
                        ),
                        dhtml.Br(),
                        dhtml.Label(
                            ['Select EV Number to Forecast:'
                            ],
                            style={
                                "textAlign": "center"
                            }
                        ),
                        dcc.Dropdown(
                            id="column_dropdown",
                            options= [{
                                'label': col,
                                'value': col} for col in list(frames_dict[dataframes[0]].columns[1:])
                                      ],
                            value=list(frames_dict[dataframes[0]].columns[1:])[0],
                            searchable=False
                        ),
                    ],
                    className="three columns",
                    id="dashboard-info",
                    style=pretty_container
                ),
                dhtml.Div(
                    [
                        dhtml.Div(
                            [dcc.Graph(id="forecasting_graph")],
                            id="forecastingGraphContainer",
                            style=pretty_container,
                        ),
                    ],
                    id="right-column",
                    className="eight columns",
                    style={
                        "display":"flex",
                        "flex-direction":"column"
                    }
                ),
            ],
            className="row",
            style={
                "display":"flex"
            }
        ),
        dhtml.Div(
            [
                dhtml.Div(
                    [
                        dhtml.H6(
                            "Peak Shaving Algorithm",
                            style={
                                "textAlign":"center"
                            }
                        ),
                        dhtml.Br(),
                        dhtml.P(
                            "This figure will contain generated peak-shaving data based on different desired peak loads.",
                            className="description_label"
                        ),
                        dhtml.P(
                            "Select Optimal Peak-Shaving Load:"
                        ),
                        dcc.Slider(
                            id="peak_shaving_slider",
                            min=100000,
                            max=200000,
                            value=100000,
                            marks={
                                100000: '100K MV',
                                150000: '150K MV',
                                200000: '200K MV'
                            }
                        ),
                    ],
                    className="three columns",
                    id="peak-shaving-info",
                    style=pretty_container,
                ),
                dhtml.Div(
                    [
                        dhtml.Div(
                            [
                                dcc.Graph(
                                    id="peak_shaving_graph",
                                ),
                            ],
                            style=pretty_container
                        )
                    ],
                    className="eight columns",
                    style={
                        "display":"flex",
                        "flex-direction":"column"
                    }
                )
            ],
            className="row"
        )
    ],
)

# %%
# Create callback for current time
@app.callback(Output('live_clock', 'children'),
              [Input("interval-component", "n_intervals")])
def update_time(n):
    return "Date and Time: %s" % (datetime.datetime.now(timezone('Canada/Atlantic')).strftime("%A, %d %B %Y %I:%M:%S %p"))

# %%
# Create callback for current temperature and conditions
@app.callback(Output('current_weather', 'children'),
                     [Input("weather-interval", "n_intervals")])
def update_weather(n):
    ec_en = ECData(station_id='NB/s0000250')
    weather = ec_en.conditions
    # current weather and conditions
    global current_temperature, current_conditions
    current_temperature = weather['temperature']['value']
    current_conditions = weather['condition']['value']
    return "Current Weather: %s °C and %s Conditions" % (current_temperature, current_conditions)

# %%
# Callback to update ev_number column selection with resolution dropdown selection
@app.callback(Output('column_dropdown', 'options'),
             [Input('df_dropdown', 'value')])
def update_ev_number_dropdown(df_name):
    return [{'label': i, 'value': i} for i in frames_dict[df_name].columns[1:]]

# %%
# Callback to update forecasting graph with ev number column selection
@app.callback(Output('forecasting_graph', 'figure'),
             [Input('df_dropdown', 'value'), Input('column_dropdown', 'value'), Input("forecasting-interval", "n_intervals")])
def update_forecasting_graph(df_name, column, n):
    global frames_dict
    build_dataframes()
    dataframes = list(frames_dict.keys())
    channels = frames_dict[dataframes[0]]

    if df_name == None or column == None:
        df_name = dataframes[0]
        column = frames_dict[df_name].columns.values[1]
        traces = plotly.graph_objs.Scatter(x=frames_dict[df_name]["datetime"], y=frames_dict[df_name][column])
    else:
        traces = plotly.graph_objs.Scatter(x=frames_dict[df_name]["datetime"], y=frames_dict[df_name][column])
    return {
        'data': [traces],
        'layout': plotly.graph_objs.Layout(
            title = 'EV Demand Forecasting - {}'.format(column),
            xaxis = 
            {
                'title': 'Date/time'
            },
            yaxis =
            {
                'title': 'Demand'
            },
        )
    }

# %%
# Callback to update peak-shaving graph with dropdown of peak load selection
@app.callback(Output('peak_shaving_graph', 'figure'),
             [Input('peak_shaving_slider', 'value')])
def update_peak_shaving_graph(peak_shaving_value):
    global peak_shaving_df
    build_peak_shaving_df()
    
    traces=plotly.graph_objs.Scatter(x=peak_shaving_df["datetime"], y=peak_shaving_df["demand"])
    layout = plotly.graph_objs.Layout(
        title = 'Peak Shaving',
        xaxis = {'title': 'Date/Time'},
        yaxis = {'title': 'Demand'},
        shapes = [
                dict(
                    type= 'line',
                    yref = "y",
                    xref = "x",
                    x0=peak_shaving_df["datetime"].iloc[0],
                    x1=peak_shaving_df["datetime"].iloc[-1],
                    y0=peak_shaving_value,
                    y1=peak_shaving_value
                )
            ])
    return {
        'data': [traces],
        'layout': layout
    }

# %%
if __name__ == '__main__':
    app.run_server(debug=True, host='0.0.0.0', port=5006)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-20-5366ec8d8a90> in <module>
#       1 if __name__ == '__main__':
# ----> 2     app.run_server(debug=True, host='0.0.0.0', port=5006)
#
# ~/miniconda3/envs/dash/lib/python3.8/site-packages/jupyter_dash/jupyter_app.py in run_server(self, mode, width, height, inline_exceptions, **kwargs)
#     317                 )
#     318
# --> 319         wait_for_app()
#     320
#     321         if JupyterDash._in_colab:
#
# ~/miniconda3/envs/dash/lib/python3.8/site-packages/retrying.py in wrapped_f(*args, **kw)
#      47             @six.wraps(f)
#      48             def wrapped_f(*args, **kw):
# ---> 49                 return Retrying(*dargs, **dkw).call(f, *args, **kw)
#      50
#      51             return wrapped_f
#
# ~/miniconda3/envs/dash/lib/python3.8/site-packages/retrying.py in call(self, fn, *args, **kwargs)
# ...
